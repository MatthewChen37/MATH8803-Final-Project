# %% [markdown]
# ### Neurolib Attempt

# %%
# %load_ext autoreload
# %autoreload 2

from Jansen_Rit_Neurolib_Model import UniformlyDistributedNoise, JansenRitNode, SingleJansenRitMass, JansenRitNetwork
import matplotlib.pyplot as plt
import numpy as np
import symengine as se
from IPython.display import display
from jitcdde import input as system_input
from neurolib.models.multimodel import MultiModel, ThalamicNode
from neurolib.models.multimodel.builder.base.constants import LAMBDA_SPEED
from neurolib.models.multimodel.builder.base.network import Network, Node
from neurolib.models.multimodel.builder.base.neural_mass import NeuralMass
from neurolib.utils.functions import getPowerSpectrum
from neurolib.utils.stimulus import Input, OrnsteinUhlenbeckProcess, StepInput
from neurolib.utils.loadData import Dataset

# %%
# init model - fix seed for reproducibility (random init. conditions)
jr_model = MultiModel.init_node(JansenRitNode(seed=42))

# see parameters
print("Parameters:")
display(jr_model.params)
print("")

# see describe
print("Describe:")
display(jr_model.model_instance.describe())
# Out:
# Parameters:
# {'JRnode_0.JRmass_0.A': 3.25,
#  'JRnode_0.JRmass_0.B': 22.0,
#  'JRnode_0.JRmass_0.a': 0.1,
#  'JRnode_0.JRmass_0.b': 0.05,
#  'JRnode_0.JRmass_0.v0': 6.0,
#  'JRnode_0.JRmass_0.v_max': 0.005,
#  'JRnode_0.JRmass_0.r': 0.56,
#  'JRnode_0.JRmass_0.C': 135.0,
#  'JRnode_0.JRmass_0.lambda': 10.0,
#  'JRnode_0.JRmass_0.input_0.type': 'UniformlyDistributedNoise',
#  'JRnode_0.JRmass_0.input_0.low': 0.12,
#  'JRnode_0.JRmass_0.input_0.high': 0.32,
#  'JRnode_0.JRmass_0.input_0.n': 1,
#  'JRnode_0.JRmass_0.input_0.seed': 42,
#  'duration': 2000,
#  'dt': 0.1,
#  'seed': None,
#  'backend': 'jitcdde',
#  'name': 'JRnode',
#  'description': 'Jansen-Rit node',
#  'N': 1,
#  'Cmat': array([[0.]]),
#  'sampling_dt': 0.1}
# Describe:
# {'index': 0,
#  'name': 'Jansen-Rit node',
#  'num_masses': 1,
#  'num_num_state_variables': 7,
#  'num_noise_variables': 1,
#  'masses': [{'index': 0,
#    'name': 'Jansen-Rit mass',
#    'mass_type': None,
#    'num_state_variables': 7,
#    'num_noise_variables': 1,
#    'state_variable_names': ['v_pyr',
#     'dv_pyr',
#     'v_exc',
#     'dv_exc',
#     'v_inh',
#     'dv_inh',
#     'r_mean_EXC'],
#    'params': {'A': 3.25,
#     'B': 22.0,
#     'a': 0.1,
#     'b': 0.05,
#     'v0': 6.0,
#     'v_max': 0.005,
#     'r': 0.56,
#     'C': 135.0,
#     'lambda': 10.0,
#     'input_0': {'type': 'UniformlyDistributedNoise',
#      'low': 0.12,
#      'high': 0.32,
#      'n': 1,
#      'seed': 42}}}]}

# %%
# run model for 5 seconds - all in ms
jr_model.params["sampling_dt"] = 1.0
jr_model.params["duration"] = 5000
jr_model.params["backend"] = "jitcdde"
jr_model.run()
# Out:
# /tmp/jitcxde_ufyuto6f/jitced_1.c: In function 'get_past_anchors':
# /tmp/jitcxde_ufyuto6f/jitced_1.c:176: warning: ignoring '#pragma omp atomic' [-Wunknown-pragmas]
#   176 |  #pragma omp atomic capture
#       |
# /tmp/jitcxde_ufyuto6f/jitced_1.c:190: warning: ignoring '#pragma omp critical' [-Wunknown-pragmas]
#   190 |   #pragma omp critical(pws)
#       |
# /tmp/jitcxde_ufyuto6f/jitced_1.c: In function 'get_recent_state':
# /tmp/jitcxde_ufyuto6f/jitced_1.c:285: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   285 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# In file included from /tmp/jitcxde_ufyuto6f/jitced_1.c:364:
# /tmp/jitcxde_ufyuto6f/f.c: In function 'eval_f':
# /tmp/jitcxde_ufyuto6f/f.c:1: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#     1 | #pragma omp parallel sections
#       |
# /tmp/jitcxde_ufyuto6f/f.c:3: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#     3 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/f.c:5: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#     5 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/f.c:7: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#     7 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/f.c:9: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#     9 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/f.c:11: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#    11 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/f.c:13: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#    13 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/f.c:15: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#    15 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/f.c:17: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#    17 | #pragma omp section
#       |
# /tmp/jitcxde_ufyuto6f/jitced_1.c: In function 'get_next_step':
# /tmp/jitcxde_ufyuto6f/jitced_1.c:387: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   387 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# /tmp/jitcxde_ufyuto6f/jitced_1.c:393: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   393 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# /tmp/jitcxde_ufyuto6f/jitced_1.c:398: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   398 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# /tmp/jitcxde_ufyuto6f/jitced_1.c:407: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   407 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# Using default integration parameters.
# 100%|██████████| 5000/5000 [00:00<00:00, 19068.19it/s]

# %%
_, axs = plt.subplots(
    nrows=2, ncols=1
)

axs[0].plot(jr_model.t, jr_model.v_exc.T - jr_model.v_inh.T, color="k")
axs[0].set_ylabel("LFP")
axs[1].plot(jr_model.t, jr_model.r_mean_EXC.T * 1000, color="navy")
axs[1].set_ylabel("PYR r [Hz]")
axs[1].set_xlabel("time [sec]")
# Out:
# Text(0.5, 0, 'time [sec]')

# %%
# First we load the structural data set from the Human Connectome Project 
ds = Dataset("hcp")

# %%
jc_network = MultiModel(JansenRitNetwork(connectivity_matrix=ds.Cmat, delay_matrix = ds.Dmat, seed=0))
jc_network.params["duration"] = 5000
jc_network.params["sampling_dt"] = 0.004

# %%
jc_network.run()
# Out:
# /home/hice1/mchen439/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# /tmp/jitcxde_ip77abwd/jitced_2.c: In function 'get_past_anchors':
| #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:705: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   705 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:707: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   707 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:709: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   709 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:711: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   711 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:713: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   713 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:715: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   715 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:717: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   717 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:719: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   719 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:721: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   721 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:723: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   723 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:725: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   725 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:727: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   727 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:729: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   729 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:731: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#   731 | #pragma omp section
#       |
# ...
#  1119 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1121: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1121 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1123: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1123 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1125: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1125 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1127: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1127 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1129: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1129 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1131: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1131 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1133: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1133 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1135: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1135 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1137: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1137 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1139: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1139 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1141: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1141 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1143: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1143 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1145: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1145 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1147: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1147 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1149: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1149 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1151: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1151 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1153: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1153 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1155: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1155 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1157: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1157 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1159: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1159 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1161: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1161 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1163: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1163 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1165: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1165 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1167: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1167 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1169: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1169 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1171: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1171 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1173: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1173 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1175: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1175 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1177: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1177 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1179: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1179 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1181: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1181 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1183: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1183 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1185: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1185 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1187: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1187 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1189: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1189 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1191: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1191 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1193: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1193 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1195: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1195 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1197: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1197 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1199: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1199 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1201: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1201 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1203: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1203 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1205: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1205 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1207: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1207 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1209: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1209 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1211: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1211 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1213: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1213 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1215: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1215 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1217: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1217 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1219: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1219 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1221: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1221 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1223: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1223 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1225: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1225 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1227: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1227 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1229: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1229 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1231: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1231 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1233: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1233 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1235: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1235 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1237: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1237 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1239: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1239 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1241: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1241 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1243: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1243 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1245: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1245 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1247: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1247 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1249: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1249 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1251: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1251 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1253: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1253 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1255: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1255 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1257: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1257 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1259: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1259 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1261: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1261 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1263: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1263 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1265: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1265 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1267: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1267 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1269: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1269 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1271: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1271 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1273: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1273 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1275: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1275 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1277: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1277 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1279: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1279 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/f.c:1281: warning: ignoring '#pragma omp section' [-Wunknown-pragmas]
#  1281 | #pragma omp section
#       |
# /tmp/jitcxde_ip77abwd/jitced_2.c: In function 'get_next_step':
# /tmp/jitcxde_ip77abwd/jitced_2.c:393: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   393 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# /tmp/jitcxde_ip77abwd/jitced_2.c:399: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   399 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# /tmp/jitcxde_ip77abwd/jitced_2.c:404: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   404 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# /tmp/jitcxde_ip77abwd/jitced_2.c:413: warning: ignoring '#pragma omp parallel' [-Wunknown-pragmas]
#   413 |  #pragma omp parallel for schedule(dynamic, 1)
#       |
# Using default integration parameters.
#   0%|          | 72/20000 [00:58<3:44:13,  1.48it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 jc_network.run()
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/neurolib/models/multimodel/model.py:149, in MultiModel.run(self, chunkwise, chunksize, bold, append, append_outputs, continue_run, noise_input)
#     146 self.initializeRun(initializeBold=bold)
#     148 if chunkwise is False:
# --> 149     self.integrate(append_outputs=append, simulate_bold=bold, noise_input=noise_input)
#     150     if continue_run:
#     151         self.setInitialValuesToLastState()
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/neurolib/models/multimodel/model.py:200, in MultiModel.integrate(self, append_outputs, simulate_bold, noise_input)
#     198 if noise_input is None:
#     199     noise_input = self._init_noise_inputs(self.params["backend"])
# --> 200 result = self.model_instance.run(
#     201     duration=self.params["duration"],
#     202     dt=dt,
#     203     noise_input=noise_input,
#     204     backend=self.params["backend"],
#     205     return_xarray=True,
#     206 )
#     207 self.storeOutputsAndStates(result, append=append_outputs)
#     208 # force bold if params['bold'] == True
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/neurolib/models/multimodel/builder/base/backend.py:53, in timer.<locals>.decorator(*args, **kwargs)
#      50 @wraps(method)
#      51 def decorator(*args, **kwargs):
#      52     time_start = time.time()
# ---> 53     result = method(*args, **kwargs)
#      54     logging.info(f"`{method.__name__}` call took {time.time() - time_start:.2f} s")
#      55     return result
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/neurolib/models/multimodel/builder/base/backend.py:592, in BackendIntegrator.run(self, duration, dt, noise_input, backend, return_xarray, **kwargs)
#     590 # update initial state
#     591 self.backend_instance.initial_state = self.initial_state.copy()
# --> 592 times, result = self.backend_instance.run(
#     593     duration=duration,
#     594     dt=dt,
#     595     noise_input=noise_input,
#     596     symbol_params=self.symbol_params,
#     597     float_params=self.float_params,
#     598     **kwargs,
#     599 )
#     600 logging.info("Integration done.")
#     601 assert times.shape[0] == result.shape[1]
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/neurolib/models/multimodel/builder/base/backend.py:480, in JitcddeBackend.run(self, duration, dt, noise_input, **kwargs)
#     478 times = np.arange(dt, duration + dt, dt)
#     479 logging.info(f"Integrating for {times.shape[0]} time steps...")
# --> 480 result = np.vstack([self.dde_system.integrate(time) for time in tqdm(times)]).T
#     481 return times, result
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/neurolib/models/multimodel/builder/base/backend.py:480, in <listcomp>(.0)
#     478 times = np.arange(dt, duration + dt, dt)
#     479 logging.info(f"Integrating for {times.shape[0]} time steps...")
# --> 480 result = np.vstack([self.dde_system.integrate(time) for time in tqdm(times)]).T
#     481 return times, result
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/jitcdde/_jitcdde.py:1591, in jitcdde_input.integrate(self, target_time)
#    1589 if target_time>self.input_duration:
#    1590 	warn("Integrating beyond duration of input. From now on, the input will be extrapolated. You very likely do not want this. Instead define a longer input or stop integrating.")
# -> 1591 return super().integrate(target_time)[:self.input_base_n]
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/jitcdde/_jitcdde.py:798, in jitcdde.integrate(self, target_time)
#     795 	warn("You did not explicitly handle initial discontinuities. Proceed only if you know what you are doing. This is only fine if you somehow chose your initial past such that the derivative of the last anchor complies with the DDE. In this case, you can set the attribute `initial_discontinuities_handled` to `True` to suppress this warning. See https://jitcdde.rtfd.io/#discontinuities for details.")
#     797 while self.DDE.get_t() < target_time:
# --> 798 	if self.try_single_step(self.dt):
#     799 		self.DDE.accept_step()
#     801 result = self.DDE.get_recent_state(target_time)
#
# File ~/scratch/miniconda3/envs/MATH8803/lib/python3.11/site-packages/jitcdde/_jitcdde.py:806, in jitcdde.try_single_step(self, length)
#     805 def try_single_step(self,length):
# --> 806 	self.DDE.get_next_step(length)
#     808 	if self.DDE.past_within_step:
#     809 		self.last_pws = self.DDE.past_within_step
#
# KeyboardInterrupt:
